# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
x = [1, 2, 3, 4, 5]
y = [18, 20, 25, 30, 40]

# %%
plt.plot(x, y);
plt.title('Simple Line Plot');
plt.xlabel('x-axis label');
plt.ylabel('y-axis label');
plt.grid(True)

# %%
months = ['Jan', 'Feb', 'Mar', 'Apr']
revenue = [100, 200, 300, 400]
plt.bar(months, revenue);

# %%
mark50 = np.random.randint(0, 100, 50)
mark50
# Out:
# array([29, 22, 65, 13, 85, 56,  4, 27, 49, 66, 71, 83, 71, 51,  8, 91, 59,
#        85, 21, 10, 22,  3, 57,  1, 25,  6, 53, 95, 12, 15, 35, 18,  9, 15,
#        65, 66, 41, 50, 82, 47, 37, 72, 80, 90, 57, 56, 16, 85, 49, 59])

# %%
plt.hist(mark50);
plt.xlabel('Marks')
plt.ylabel('No. of Students')
# Out:
# Text(0, 0.5, 'No. of Students')

# %% [markdown]
# Subplots & Legends

# %%
days = [1, 2, 3, 4, 5]
original_price = [10, 20, 25, 38, 40]
predict_price = [8, 21, 25, 28, 35]

# %%
plt.plot(days, original_price)
plt.plot(days, predict_price)
